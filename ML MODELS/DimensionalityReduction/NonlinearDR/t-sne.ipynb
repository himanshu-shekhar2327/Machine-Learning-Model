# %% [markdown]
# # Basic t-SNE implementataion

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(n_components = 2 , random_state = 42)
X_embedded = tsne.fit_transform(X)

plt.scatter(X_embedded[: , 0] , X_embedded[: , 1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import matplotlib.pyplot as plt
#       4 tsne = TSNE(n_components = 2 , random_state = 42)
# ----> 5 X_embedded = tsne.fit_transform(X)
#       7 plt.scatter(X_embedded[: , 0] , X_embedded[: , 1])
#       8 plt.show()
#
# NameError: name 'X' is not defined

# %% [markdown]
# # Complete t-SNE Example on the IRIS Dataset

# %%
from sklearn.datasets import load_iris
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# LOad the datset
iris= load_iris()
X = iris.data
y = iris.target

# Apply TSNE
tsne = TSNE(n_components = 2, perplexity = 30 , learning_rate = 200 , random_state = 42)
X_tsne = tsne.fit_transform(X)

#Plot
plt.scatter(X_tsne[:,0] , X_tsne[: , 1] , c = y , cmap = 'viridis')
plt.colorbar()
plt.title('t-SNE visualization or Iris Datset')
plt.show()

# %% [markdown]
# # t-SNE on MNIST

# %%
from sklearn.datasets import load_digits

# Load MNIST like digits dataset
digits = load_digits()
X = digits.data
y = digits.target

# Apply t-SNE
tsne = TSNE(n_components = 2 , perplexity = 30 , learning_rate = 200 , random_state = 42)
X_tsne = tsne.fit_transform(X)

# Plot clusters
plt.figure(figsize = (8 , 6))
plt.scatter(X_tsne[: , 0] , X_tsne[:  , 1] , c = y , cmap = 'tab10')
plt.colorbar()
plt.title('t-SNE visualization of handwritten digits')
plt.show()
