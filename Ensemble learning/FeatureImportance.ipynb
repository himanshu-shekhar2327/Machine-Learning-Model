# %%
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier

# %%
X , y = make_classification(n_samples=5,n_classes=2,n_features=2,
                           n_informative=2,n_redundant=0,
                           random_state=0)

# %%
clf = DecisionTreeClassifier()
clf.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clf)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[0] <= -0.875\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[0] <= 1.01\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
clf.feature_importances_
# Out:
# array([1., 0.])

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=2)
rf.fit(X,y)
# Out:
# RandomForestClassifier(n_estimators=2)

# %%
rf.feature_importances_
# Out:
# array([0.77777778, 0.22222222])

# %%
rf.estimators_
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=1538257375),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1866002368)]

# %%
print(rf.estimators_[0].feature_importances_)
print(rf.estimators_[1].feature_importances_)
# Out:
# [1. 0.]
# [0.55555556 0.44444444]

# %%
# internally random forest claculate the featire importance and taking it average

# %%
# Finding the Feature Importance on the iris dataset
from sklearn.datasets import load_iris
iris = load_iris()
rnf = RandomForestClassifier(n_estimators=500,n_jobs=-1,random_state=42)
rnf.fit(iris["data"],iris["target"])
# Out:
# RandomForestClassifier(n_estimators=500, n_jobs=-1, random_state=42)

# %%
print(iris.feature_names)
rnf.feature_importances_
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# array([0.11249225, 0.02311929, 0.44103046, 0.423358  ])

# %%
from sklearn.ensemble import ExtraTreesClassifier
et = ExtraTreesClassifier(n_estimators=100,n_jobs=-1,random_state=42)
et.fit(iris['data'],iris['target'])
# Out:
# ExtraTreesClassifier(n_jobs=-1, random_state=42)

# %%
et.feature_importances_
# Out:
# array([0.09176665, 0.05429184, 0.42817653, 0.42576497])
