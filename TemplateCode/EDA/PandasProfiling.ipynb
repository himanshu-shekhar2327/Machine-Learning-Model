# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# pip install --upgrade pip setuptools wheel
# Out:
# ...
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# # pip install ydata-profiling
# %pip install ydata-profilingAA
# Out:
# ...
#   Using cached ydata_profiling-4.18.0-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# ...
#   Using cached pyyaml-6.0.3-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached minify_html-0.18.1-cp312-cp312-win_amd64.whl.metadata (18 kB)
# ...
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached phik-0.12.5-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# ...
#   Using cached multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# ...
#   Using cached typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached wordcloud-1.9.5-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# ...
#   Using cached dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# ...

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\himan\AppData\Local\Programs\Python\Python312\python.exe

# %%
# !{sys.executable} -m pip install ydata-profiling
# Out:
# ...
#   Using cached ydata_profiling-4.18.0-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# ...
#   Using cached visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached phik-0.12.5-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# ...
#   Using cached ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached wordcloud-1.9.5-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# ...
# Using cached ydata_profiling-4.18.0-py2.py3-none-any.whl (398 kB)
# Using cached ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Using cached matplotlib-3.10.0-cp312-cp312-win_amd64.whl (8.0 MB)
# Using cached phik-0.12.5-cp312-cp312-win_amd64.whl (676 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached visions-0.8.1-py3-none-any.whl (105 kB)
# Using cached wordcloud-1.9.5-cp312-cp312-win_amd64.whl (307 kB)
# ...
#
# ...

# %% [markdown]
# # Assistant
# This error occurs because the `ydata_profiling` module is not installed in your Python environment. The error message "No module named 'ydata_profiling'" indicates that Python cannot find this package.
#
# Would you like me to provide the corrected code?

# %%
# First, install the required package
# !pip install ydata-profiling

# Then import and use it
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')

# Note: In older versions, this package was called 'pandas-profiling'
# If the above doesn't work, you might try:
# !pip install pandas-profiling
# from pandas_profiling import ProfileReport
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
