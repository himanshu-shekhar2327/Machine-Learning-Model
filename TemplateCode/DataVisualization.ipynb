# %%
import matplotlib.pyplot as plt

# Set up color theme
colors_pie = ['#2ECC71', '#E74C3C']  # Green = No Disease, Red = Disease

# Create figure and axes
fig, axes = plt.subplots(1, 1, figsize=(6, 6))

# Plot pie chart
axes.pie(
    data['HeartDisease'].value_counts(),
    labels=['No Heart Disease', 'Heart Disease'],
    autopct='%1.1f%%',
    colors=colors_pie,
    startangle=90,
    explode=(0.05, 0.05),
    shadow=True,
    textprops={'fontsize': 12, 'fontweight': 'bold'}
)

# Title
axes.set_title('Heart Disease Proportion', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       7 fig, axes = plt.subplots(1, 1, figsize=(6, 6))
#       9 # Plot pie chart
#      10 axes.pie(
# ---> 11     data['HeartDisease'].value_counts(),
#      12     labels=['No Heart Disease', 'Heart Disease'],
#      13     autopct='%1.1f%%',
#      14     colors=colors_pie,
#      15     startangle=90,
#      16     explode=(0.05, 0.05),
#      17     shadow=True,
#      18     textprops={'fontsize': 12, 'fontweight': 'bold'}
#      19 )
#      21 # Title
#      22 axes.set_title('Heart Disease Proportion', fontsize=14, fontweight='bold')
#
# NameError: name 'data' is not defined

# %%
# Correlation Heatmap
num_cols = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak', 'FastingBS']
plt.figure(figsize=(8,6))
sns.heatmap(X[num_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap (Numerical Features)")
plt.show()
